# %% [markdown]
# #### 1. Set-up

# %%
import sys
sys.path.insert(0, "../..")
from shared.utils import chat, list_models

# %% [markdown]
# #### 2. Check available models

# %%
list_models()
# Out:
# NAME                       ID              SIZE      MODIFIED
# qwen2.5:14b                7cdf5a0187d5    9.0 GB    About an hour ago
# qwen2.5-coder:14b          9ec8897f747e    9.0 GB    4 hours ago
# nomic-embed-text:latest    0a109f422b47    274 MB    4 hours ago
# qwen2.5-coder:1.5b-base    02e0f2817a89    986 MB    4 hours ago

# %% [markdown]
# #### 3. First Local LLM call (No API key needed)

# %%
response = chat("Explain agentic AI in three sentences.")
print(response)
# Out:
# Agentic AI refers to advanced artificial intelligence systems that possess the ability to act autonomously towards specific goals, often requiring a high degree of adaptability, decision-making capability, and understanding of complex social environments. These AI systems can operate with a level of initiative, learning from their experiences and interacting with other entities in ways that reflect more human-like agency. Applications of agentic AI can be found in autonomous vehicles, personalized healthcare, and interactive virtual agents, where the AI not only responds to inputs but also takes actions to progress towards its objectives.

# %% [markdown]
# #### 4. System Prompts

# %%
response = chat(
    "What are the key design patterns for AI agents?",
    system="You are a concise technical instructor. Keep it under 200 words."
)
print(response)
# Out:
# Design patterns in AI agents focus on structuring agents to efficiently interact with environments, learn from data, and make decisions. Key patterns include:
#
# 1. **Reinforcement Learning Agents**: These agents learn by interacting with their environment, receiving feedback in the form of rewards or penalties, and adjusting their strategies to maximize cumulative rewards. Algorithms like Q-learning and policy gradients fall under this category.
#
# 2. **Decision Tree Agents**: These agents use decision trees to model decisions and their possible consequences. They are simple yet effective for classification and regression tasks, leveraging if-then rules derived from data.
#
# 3. **Markov Decision Process (MDP) Agents**: These are foundational in reinforcement learning, where the agent aims to navigate an environment to achieve a goal without knowing the exact rules. MDPs define a framework for making decisions in stochastic environments.
#
# ...

# %% [markdown]
# #### 5. Streaming

# %%
from shared.utils import chat_stream
chat_stream("Write a Python function that checks if a number is prime.")
# Out:
# Certainly! To check if a number is prime, you can write a Python function that determines if the number is greater than 1 and has no divisors other than 1 and itself. Here's a simple implementation:
#
# ```python
# def is_prime(n):
#     """
#     Check if a number is prime.
#
#     Parameters:
#     n (int): The number to check.
#
#     Returns:
#     bool: True if n is a prime number, False otherwise.
#     """
#     if n <= 1:
#         return False
#     if n <= 3:
#         return True
#     if n % 2 == 0 or n % 3 == 0:
#         return False
#     i = 5
#     while i * i <= n:
#         if n % i == 0 or n % (i + 2) == 0:
#             return False
#         i += 6
#     return True
#
# # Example usage:
# print(is_prime(29))  # Output: True
# print(is_prime(15))  # Output: False
# ```
#
# ### Explanation:
# 1. **Initial Checks**:
#    - If `n` is less than or equal to 1, it's not a prime number.
# ...
